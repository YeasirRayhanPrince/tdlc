# %%
# UNCOMMENT IF USING COLAB

# from google.colab import drive
# drive.mount('/content/gdrive')


# !pip install shapely

# %%
# LOADS 3 FILES
#     1. 311_06.csv -> contains 311 Public complaints data from New York City
#     2. CrimeData.csv -> Multi-year crime records
#     3. Regions.csv -> Geographical divisions of the city into precincts

import pandas as pd
import numpy as np
import shapely.wkt
from shapely.geometry import Point, Polygon, MultiPolygon

# %%
# Change the 'year' and file locations according to your dataset
year = '2006'
# file311 = "RawData/311_06.csv"
# fileCrime = "RawData/CrimeData.csv"
# fileRegions = "RawData/Regions.csv"
file311 = "../Dataset/311_Service_Requests_for_2006.csv"
fileCrime = "../Dataset/NYPD_Complaint_Data_Historic.csv"
fileRegions = "../Dataset/nypp.csv"

# %%
# Extract:
#     1. Relevant columns
#     2. Relevant types of complaints, from the 'Complaint Type' column

# data311 = pd.read_csv(file311,low_memory=True)
# relevantColumns311 = ['Created Date','Latitude','Longitude','Complaint Type']       # columns
# relevantComplaints311 = ['Blocked Driveway','Building/Use','Noise','Safety']        # complaint types / anomalies (rows)
# finalColumns311 = ['Created Date','Complaint Type','Precincts']
# data311 = data311[relevantColumns311]
# data311 = data311.loc[(data311['Complaint Type'] == 'Blocked Driveway') | (data311['Complaint Type'] == 'Building/Use') | (data311['Complaint Type'] == 'Noise') | (data311['Complaint Type'] == 'Safety')]
# print('Anomalies preprocessed!!!')




# chunksize = 10000
# relevantColumns311 = ['Created Date','Latitude','Longitude','Complaint Type']
# relevantComplaints311 = ['Blocked Driveway','Building/Use','Noise','Safety']
# finalColumns311 = ['Created Date','Complaint Type','Precincts']

# # Iterate over the chunks of data and filter relevant columns and complaints
# data311_filtered = pd.DataFrame(columns=relevantColumns311)
# for chunk in pd.read_csv(file311, low_memory=True, chunksize=chunksize):
#     chunk = chunk[relevantColumns311]
#     chunk = chunk.loc[chunk['Complaint Type'].isin(relevantComplaints311)]
#     data311_filtered = pd.concat([data311_filtered, chunk])

# data311 = data311_filtered
# del data311_filtered

# print('Anomalies preprocessed!!!')



chunksize = 100000
relevantColumns311 = ['Created Date','Latitude','Longitude','Complaint Type']
# relevantComplaints311 = ['Blocked Driveway','Building/Use','Noise','Safety']
relevantComplaints311 = ['Maintenance or Facility', 'Consumer Complaint', 'Overgrown Tree/Branches', 'Broken Parking Meter', 'Taxi Complaint']
finalColumns311 = ['Created Date','Complaint Type','Precincts']

# select only the first chunk of data
data311 = pd.read_csv(file311, low_memory=True, nrows=chunksize)

# keep only the relevant columns
data311 = data311[relevantColumns311]

# keep only the relevant complaints
data311 = data311.loc[data311['Complaint Type'].isin(relevantComplaints311)]

print('Anomalies preprocessed!!!')
data311.shape
# Out:
# Anomalies preprocessed!!!
# c:\Users\Asus\AppData\Local\Programs\Python\Python37\lib\site-packages\IPython\core\interactiveshell.py:3331: DtypeWarning: Columns (7,8,17,18,37,38,41,42,43,44,45,47,48) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
# (5641, 4)

# %%
# Extract:
#     1. Relevant columns
#     2. Relevant types of crimes, from the 'OFNS_DESC' column

# crimeData = pd.read_csv(fileCrime, low_memory=False)

# mylist = []
# for chunk in  pd.read_csv(fileCrime, low_memory=True, chunksize=10000):
#     mylist.append(chunk)
# crimeData = pd.concat(mylist, axis= 0)
# del mylist

# crimeData

# relevantColumnsCR = ['CMPLNT_TO_DT','CMPLNT_TO_TM','CMPLNT_FR_DT','RPT_DT','Lat_Lon','Latitude','Longitude','OFNS_DESC']
# finalColumnsCR = ['Date','OFNS_DESC','CMPLNT_TO_TM','Longitude','Latitude','Precincts']
# relevantCrimesCR = ['ROBBERY', 'BURGLARY', 'FELONY ASSAULT','GRAND LARCENY']

# locations = pd.read_csv("RawData/Regions.csv", low_memory=False)
# crime2006 = crimeData.loc[crimeData['RPT_DT'].str.endswith(year)]
# crime2006 = crime2006[relevantColumnsCR]
# crime2006 = crime2006.loc[(crime2006['OFNS_DESC'] == 'ROBBERY') | (crime2006['OFNS_DESC'] == 'BURGLARY') | (crime2006['OFNS_DESC'] == 'FELONY ASSAULT') | (crime2006['OFNS_DESC'] == 'GRAND LARCENY')]
# print('Crime Preprocessed!!!')





chunksize = 100000
relevantColumnsCR = ['CMPLNT_TO_DT','CMPLNT_TO_TM','CMPLNT_FR_DT','RPT_DT','Lat_Lon','Latitude','Longitude','OFNS_DESC']
finalColumnsCR = ['Date','OFNS_DESC','CMPLNT_TO_TM','Longitude','Latitude','Precincts']
relevantCrimesCR = ['ROBBERY', 'BURGLARY', 'FELONY ASSAULT','GRAND LARCENY']

# select only the first chunk of data
crimeData = pd.read_csv(fileCrime, low_memory=True, nrows=chunksize)

# keep only the relevant columns
crimeData = crimeData[relevantColumnsCR]

# keep only the relevant crimes
crimeData = crimeData.loc[crimeData['OFNS_DESC'].isin(relevantCrimesCR)]

crime2006 = crimeData
del crimeData

print('Crime Preprocessed!!!')
crime2006.shape
# Out:
# Crime Preprocessed!!!
# (18990, 8)

# %%
# Load the regions and store a MultiPolygon object(corresponding to the geometry of the region) and the precinct number

locations = pd.read_csv(fileRegions, low_memory=False)
precincts = {}
for index, row in locations.iterrows():
  precincts[row['Precinct']] = shapely.wkt.loads(row['the_geom'])

print('Locations loaded!!!')
# Out:
# Locations loaded!!!

# %%
# Extracts the latitude/longitude information of each 311 complaint reported
# And assigns it to one of the precincts defined earlier in form of a MultiPolygon

pos = 0
prec = np.ndarray((data311.shape[0],))

for index,row in data311.iterrows():

  poo = Point(row['Longitude'],row['Latitude'])  
  for key,val in precincts.items():
    if poo.within(val):
      prec[pos] = key
      break

  pos=pos+1
  if(pos%1000 == 0):
    print ("processed "+str(pos)+" records!!")

# Adds the precincts information to the dataset
data311['Precincts'] = prec.astype(int)
print("Done!!")

# Extract the final columns needed for training the model
data311['Precincts'] = data311['Precincts'].astype(np.int64)
data311 = data311[data311['Precincts'] >= 0]
data311 = data311[finalColumns311]

print('Anomaly Preprocessing complete!!!')
# Out:
# c:\Users\Asus\AppData\Local\Programs\Python\Python37\lib\site-packages\shapely\predicates.py:946: RuntimeWarning: invalid value encountered in within
#   return lib.within(a, b, **kwargs)
# processed 1000 records!!
# processed 2000 records!!
# processed 3000 records!!
# processed 4000 records!!
# processed 5000 records!!
# Done!!
# Anomaly Preprocessing complete!!!

# %%
# Extracts the latitude/longitude information of each crime reported
# And assigns it to one of the precincts defined earlier in form of a MultiPolygon

# Also, some preprocessing is done on the date columns as well
# To ensure that the final date column doesn't have NaN values

pos = 0
prec = np.ndarray((crime2006.shape[0],))
date = np.ndarray((crime2006.shape[0],)).astype(str)

for index,row in crime2006.iterrows():
  
  if not(str(row['CMPLNT_FR_DT']) == 'nan'):
    date[pos] = row['CMPLNT_FR_DT']
  elif not(str(row['CMPLNT_TO_DT']) == 'nan'):
    date[pos] = row['CMPLNT_TO_DT']
  else:
    date[pos] = row['RPT_DT']
  
  poo = Point(row['Longitude'],row['Latitude'])  
  for key,val in precincts.items():
    if poo.within(val):
      prec[pos] = key
      break

  pos=pos+1
  if(pos%1000 == 0):
    print ("processed "+str(pos)+" records!!")

# Adds the precincts information to the dataset
# Adds the dates information to the dataset

crime2006['Precincts'] = prec.astype(int)
crime2006['Date'] = date
crime2006 = crime2006[crime2006['Precincts'] >= 0]

print("Done!!")

# Extract the final columns needed for training the model
crime2006 = crime2006[finalColumnsCR]
crime2006.sort_values(['Precincts','Date','OFNS_DESC'],ascending=[True,True,True],inplace=True)
crime2006 = crime2006[crime2006['Date'].str.contains(year)]
crime2006['Precincts'] = crime2006['Precincts'].astype(np.int64)

print('Crime Preprocessing complete!!!')
# Out:
# processed 1000 records!!
# processed 2000 records!!
# processed 3000 records!!
# processed 4000 records!!
# processed 5000 records!!
# processed 6000 records!!
# processed 7000 records!!
# processed 8000 records!!
# processed 9000 records!!
# processed 10000 records!!
# processed 11000 records!!
# processed 12000 records!!
# processed 13000 records!!
# processed 14000 records!!
# processed 15000 records!!
# processed 16000 records!!
# processed 17000 records!!
# processed 18000 records!!
# Done!!
# Crime Preprocessing complete!!!

# %%
# Generates inverted dictionaries for
#     1. Date for the particular year, according to the 'year' var defined earlier
#     2. Complaints: according to the 4 categories that we are considering
#     3. Precincts: the grographical divisions of the city
#     4. Crimes: according to the 4 categories we are considering for prediction

# The final input that we feed to the Heirarchical LSTMs is in form of matrices
# These inverted indices help in conversion of the dataframe to thse matrices

daterange = pd.date_range(start='01/01/'+year,end='12/31/'+year)
daterange = daterange.strftime('%m/%d/%Y')
daterange = daterange.tolist()

inv_dict = {}
for i in range(len(daterange)):
  inv_dict[daterange[i]] = i          # output : {date: index}    # e.g. {'01/01/2006': 0, '01/02/2006': 1, ...}

inv_complaints = {}
for i in range(len(relevantComplaints311)):
  inv_complaints[relevantComplaints311[i]] = i      # output : {complaint: index}    # e.g. {'Noise - Residential': 0, 'Noise - Street/Sidewalk': 1, ...}

n_precincts = data311['Precincts'].nunique()        # output : 77
uniq_precincts = data311['Precincts'].unique()      
inv_prec = {}
for i in range(n_precincts):
  inv_prec[uniq_precincts[i]] = i                     # output : {precinct: index}    # e.g. {1: 0, 5: 1, 6: 2, ...}

inv_crimes = {}
for i in range(len(relevantCrimesCR)):
  inv_crimes[relevantCrimesCR[i]] = i               # output : {crime: index}    # e.g. {'ROBBERY': 0, 'BURGLARY': 1, 'FELONY ASSAULT': 2, 'GRAND LARCENY': 3}

# %%
# Generate the matrices for Crime (365x78x4) and 311 Complaints (365x78x4)
# Here the 2nd dimension represents the precinct and is 78, instead of 77
# This is because all the complaints/crimes with no geographical location have been assigned 0th position
# This 0th position is later discarded during the training process, but can be used if one wishes to do so

# Each matrix represents crime/complaint occurence over different categories(4), over different localities(78) over a period of 1 year(365)


# Generating the crime records matrices
matricesCR = [np.zeros((n_precincts,4),dtype=np.int64) for x in range(365)]
exceptions = 0

id1 = -1
id2 = -1
id3 = -1

for idx, row in crime2006.iterrows():
  try:
    id1 = inv_prec[row['Precincts']]
    id2 = inv_dict[row['Date']]
    id3 = inv_crimes[row['OFNS_DESC']]
    matricesCR[id2][id1][id3] = matricesCR[id2][id1][id3] + 1
  except:
    print("Exception!!!")
    print("Precincts",id1)
    print("Date",id2)
    print("Offense",id3)
    exceptions = exceptions + 1

print ('Created crime matrices!!!')

# Generating the 311 complaints records matrices
matrices311 = [np.zeros((n_precincts,4),dtype=np.int64) for x in range(365)]
exceptions = 0

for idx, row in data311.iterrows():
  try:
    id1 = inv_prec[row['Precincts']]
    id2 = inv_dict[str(row['Created Date']).split()[0]]
    id3 = inv_complaints[row['Complaint Type']]
    matrices311[id2][id1][id3] = matrices311[id2][id1][id3] + 1
  except:
    print("Exception!!!")
    print("Precincts",id1)
    print("Date",id2)
    print("Offense",id3)
    exceptions = exceptions + 1

print('Created anomaly matrices!!!')
# Out:
# Exception!!!
# Precincts -1
# Date -1
# Offense -1
# Exception!!!
# Precincts -1
# Date -1
# Offense -1
# Exception!!!
# Precincts -1
# Date -1
# Offense -1
# Exception!!!
# Precincts -1
# Date -1
# Offense -1
# Exception!!!
# Precincts -1
# Date -1
# Offense -1
# Exception!!!
# Precincts -1
# Date -1
# Offense -1
# Exception!!!
# Precincts -1
# Date -1
# Offense -1
# Exception!!!
# Precincts -1
# Date -1
# Offense -1
# Exception!!!
# Precincts -1
# Date -1
# Offense -1
# Exception!!!
# Precincts -1
# Date -1
# Offense -1
# Exception!!!
# Precincts -1
# Date -1
# Offense -1
# Exception!!!
# Precincts -1
# Date -1
# Offense -1
# Created crime matrices!!!
# Exception!!!
# Precincts 1
# Date 138
# Offense 4
# Exception!!!
# Precincts 1
# Date 145
# Offense 4
# Exception!!!
# Precincts 1
# Date 34
# Offense 4
# Exception!!!
# Precincts 1
# Date 28
# Offense 4
# Exception!!!
# Precincts 1
# Date 39
# Offense 4
# Exception!!!
# Precincts 1
# Date 36
# Offense 4
# Exception!!!
# Precincts 1
# Date 48
# Offense 4
# Exception!!!
# Precincts 1
# Date 45
# Offense 4
# Exception!!!
# Precincts 1
# Date 36
# Offense 4
# Exception!!!
# Precincts 1
# Date 35
# Offense 4
# Exception!!!
# Precincts 1
# Date 18
# Offense 4
# Exception!!!
# Precincts 1
# Date 29
# Offense 4
# Exception!!!
# Precincts 1
# Date 25
# Offense 4
# Exception!!!
# Precincts 1
# Date 12
# Offense 4
# Exception!!!
# Precincts 1
# Date 29
# Offense 4
# Exception!!!
# Precincts 1
# Date 26
# Offense 4
# Exception!!!
# Precincts 1
# Date 8
# Offense 4
# Exception!!!
# Precincts 1
# Date 13
# Offense 4
# Exception!!!
# Precincts 1
# Date 178
# Offense 4
# Exception!!!
# Precincts 1
# Date 155
# Offense 4
# Exception!!!
# Precincts 1
# Date 164
# Offense 4
# Exception!!!
# Precincts 1
# Date 166
# Offense 4
# Exception!!!
# Precincts 1
# Date 130
# Offense 4
# Exception!!!
# Precincts 1
# Date 138
# Offense 4
# Exception!!!
# Precincts 1
# Date 135
# Offense 4
# Exception!!!
# Precincts 1
# Date 125
# Offense 4
# Exception!!!
# Precincts 1
# Date 144
# Offense 4
# Exception!!!
# Precincts 1
# Date 58
# Offense 4
# Exception!!!
# Precincts 1
# Date 88
# Offense 4
# Exception!!!
# Precincts 1
# Date 57
# Offense 4
# Exception!!!
# Precincts 1
# Date 59
# Offense 4
# Exception!!!
# Precincts 1
# Date 67
# Offense 4
# Exception!!!
# Precincts 1
# Date 57
# Offense 4
# Exception!!!
# Precincts 1
# Date 46
# Offense 4
# Exception!!!
# Precincts 1
# Date 45
# Offense 4
# Exception!!!
# Precincts 1
# Date 45
# Offense 4
# Exception!!!
# Precincts 1
# Date
# Precincts 1
# Date 339
# Offense 4
# Exception!!!
# Precincts 1
# Date 301
# Offense 4
# Exception!!!
# Precincts 1
# Date 212
# Offense 4
# Exception!!!
# Precincts 1
# Date 245
# Offense 4
# Exception!!!
# Precincts 1
# Date 214
# Offense 4
# Exception!!!
# Precincts 1
# Date 254
# Offense 4
# Exception!!!
# Precincts 1
# Date 306
# Offense 4
# Exception!!!
# Precincts 1
# Date 228
# Offense 4
# Exception!!!
# Precincts 1
# Date 277
# Offense 4
# Exception!!!
# Precincts 1
# Date 235
# Offense 4
# Exception!!!
# Precincts 1
# Date 233
# Offense 4
# Exception!!!
# Precincts 1
# Date 212
# Offense 4
# Exception!!!
# Precincts 1
# Date 227
# Offense 4
# Exception!!!
# Precincts 1
# Date 273
# Offense 4
# Exception!!!
# Precincts 1
# Date 304
# Offense 4
# Exception!!!
# Precincts 1
# Date 280
# Offense 4
# Exception!!!
# Precincts 1
# Date 315
# Offense 4
# Exception!!!
# Precincts 1
# Date 274
# Offense 4
# Exception!!!
# Precincts 1
# Date 304
# Offense 4
# Exception!!!
# Precincts 1
# Date 289
# Offense 4
# Exception!!!
# Precincts 1
# Date 364
# Offense 4
# Exception!!!
# Precincts 1
# Date 301
# Offense 4
# Exception!!!
# Precincts 1
# Date 311
# Offense 4
# Exception!!!
# Precincts 1
# Date 340
# Offense 4
# Exception!!!
# Precincts 1
# Date 274
# Offense 4
# Exception!!!
# Precincts 1
# Date 284
# Offense 4
# Exception!!!
# Precincts 1
# Date 309
# Offense 4
# Exception!!!
# Precincts 1
# Date 285
# Offense 4
# Exception!!!
# Precincts 1
# Date 324
# Offense 4
# Exception!!!
# Precincts 1
# Date 297
# Offense 4
# Exception!!!
# Precincts 1
# Date 330
# Offense 4
# Exception!!!
# Precincts 1
# Date 286
# Offense 4
# Exception!!!
# Precincts 1
# Date 311
# Offense 4
# Exception!!!
# Precincts 1
# Date 332
# Offense 4
# Exception!!!
# Precincts 1
# Date 333
# Offense 4
# Exception!!!
# Precincts 1
# Date 330
# Offense 4
# Exception!!!
# Precincts 1
# Date 330
# Offense 4
# Exception!!!
# Precincts 1
# Date 351
# Offense 4
# Exception!!!
# Precincts 1
# Date 347
# Offense 4
# Exception!!!
# Precincts 1
# Date 289
# Offense 4
# Exception!!!
# Precincts 1
# Date 341
# Offense 4
# Exception!!!
# Precincts 1
# Date 363
# Offense 4
# Exception!!!
# Precincts 1
# Date 323
# Offense 4
# Exception!!!
# Precincts 1
# Date 353
# Offense 4
# Exception!!!
# Precincts 1
# Date 345
# Offense 4
# Exception!!!
# Precincts 1
# Date 352
# Offense 4
# Created anomaly matrices!!!

# %%
import pickle


# Dump the matrices using pickle, to a file
output311 = 'matrices311_NYC'
outputCrime = 'matricesCR_NYC'

file311 = open(output311,'wb')
pickle.dump(matrices311,file311)

fileCR = open(outputCrime,'wb')
pickle.dump(matricesCR,fileCR)

# To load these files, use:
# with open(filename,'rb') as toOpen:
#     data = pickle.load(toOpen)
