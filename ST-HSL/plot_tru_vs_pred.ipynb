# %%
import pickle
import numpy as np
import matplotlib.pyplot as plt

# %%
y_true = pickle.load(open('y_true.pkl', 'rb'))
y_pred = pickle.load(open('y_pred.pkl', 'rb'))

y_true = np.array(y_true)
y_pred = np.array(y_pred)

print(y_pred[0].shape)
print(y_true[0].shape)

# true = []
# pred = []

# for i in range(len(y_true)):
#     true_elems = y_true[i].reshape(-1, 1)
#     pred_elems = y_pred[i].reshape(-1, 1)
#     true.extend(true_elems)
#     pred.extend(pred_elems)

# true = np.array(true).reshape(-1, 1)
# pred = np.array(pred).reshape(-1, 1)

# print(true.shape)
# print(pred.shape)
# Out:
# (4, 80, 4)
# (4, 80, 4)

# %%
# plot y_true and y_pred for a random community
plt.figure(figsize=(20, 10))
plt.plot(true[:350, :], label="true", color="orange")
plt.plot([x*8 for x in pred[:350, :]], label="pred", color="blue")
# plt.plot(pred[:1000, :], label="pred", color="blue")
plt.legend()
# plt.savefig("sthsl_true_pred_1d.jpg")
plt.show()
